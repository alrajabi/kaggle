# %% [markdown]
# For the actual dataset, we need to be more careful about memory usage, etc.
#
# We also need to split the data set into training and validation sets.

# %% [markdown]
# Play with the data for a little bit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = bson.decode_file_iter(open('/Users/satoru/Documents/Kaggle/Cdiscount/train_example.bson', 'rb'))

for c, d in enumerate(data):
    print(c, len(d))
# Out:
# 0 3
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3
# 6 3
# 7 3
# 8 3
# 9 3
# 10 3
# 11 3
# 12 3
# 13 3
# 14 3
# 15 3
# 16 3
# 17 3
# 18 3
# 19 3
# 20 3
# 21 3
# 22 3
# 23 3
# 24 3
# 25 3
# 26 3
# 27 3
# 28 3
# 29 3
# 30 3
# 31 3
# 32 3
# 33 3
# 34 3
# 35 3
# 36 3
# 37 3
# 38 3
# 39 3
# 40 3
# 41 3
# 42 3
# 43 3
# 44 3
# 45 3
# 46 3
# 47 3
# 48 3
# 49 3
# 50 3
# 51 3
# 52 3
# 53 3
# 54 3
# 55 3
# 56 3
# 57 3
# 58 3
# 59 3
# 60 3
# 61 3
# 62 3
# 63 3
# 64 3
# 65 3
# 66 3
# 67 3
# 68 3
# 69 3
# 70 3
# 71 3
# 72 3
# 73 3
# 74 3
# 75 3
# 76 3
# 77 3
# 78 3
# 79 3
# 80 3
# 81 3

# %% [markdown]
# There are 82 dictionaries stored in data, with numerical id ('c') from 0 to 81.

# %%
data = bson.decode_file_iter(open('/Users/satoru/Documents/Kaggle/Cdiscount/train_example.bson', 'rb'))

for c, d in enumerate(data):
    print(d)
    break
# Out:
# {'_id': 0, 'imgs': [{'picture': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\xb4\x00\xb4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc
# ...

# %% [markdown]
# Each dictionary contains 3 keys: '_id', 'imgs', 'category_id'.
#
# d['imgs'] is a list of dictionaries, each of which has the key 'picture', and maps to a picture in binary representation.
#
# Look at a d['imgs'] that contains more than 1 image.

# %%
data = bson.decode_file_iter(open('/Users/satoru/Documents/Kaggle/Cdiscount/train_example.bson', 'rb'))

for c, d in enumerate(data):
    if len(d['imgs']) > 1:
        imgs = d['imgs']
        break

# %%
for img in imgs:
    picture = imread(io.BytesIO(img['picture']))
    plt.imshow(picture)
    plt.show()

# %% [markdown]
# So the images are of the same product, and the goal is to predict category_id from that.
